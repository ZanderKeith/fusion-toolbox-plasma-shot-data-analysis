# %%
# %load_ext autoreload
# %autoreload 2
from fusion_toolbox.plotting_gui.view import View

view = View()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ...
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\16125\AppData\Local\Programs\Python\Python38\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
# TypeError: update_frequency() missing 1 required positional argument: 'canvas'
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\16125\AppData\Local\Programs\Python\Python38\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
# TypeError: update_frequency() missing 1 required positional argument: 'canvas'
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\16125\AppData\Local\Programs\Python\Python38\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
# TypeError: update_frequency() missing 1 required positional argument: 'canvas'
# ...
